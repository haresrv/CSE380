# %% [markdown]
# Pandas Visualization
# Pandas Visualization makes it really easy to create plots out of a pandas dataframe and series. It also has a higher level API than Matplotlib and therefore we need less code for the same results.

# %%
#Reading csv file, that Load a data set
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
iris = pd.read_csv('bezdekIris.data', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#scatter plot
iris.plot.scatter(x='sepal_length', y='sepal_width', title='Iris Dataset')

# %%
#line chart
iris.drop(['class'], axis=1).plot.line(title='Iris Dataset')

# %%
#histogram
iris.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA0FDF5C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA10D36D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA10FBAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA1121F28>]],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix

fig, ax = plt.subplots(figsize=(12,12))
scatter_matrix(iris, alpha=1, ax=ax)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2924400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2CC0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA297A668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA299FBE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA29D0198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA29F7710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2A204A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2A48A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2A48A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2AA2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2AC9AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2AFA080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2B235F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2B4BB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2B7B128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024BA2BA26A0>]],
#       dtype=object)
